# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_line_chart(exec_time, title, fig_name):
    plt.subplots(figsize=(12, 6))
    plt.plot([100, 1000, 10000, 100000], exec_time[0], ':', linewidth=2, label='BubbleSort')
    plt.plot([100, 1000, 10000, 100000], exec_time[1], ':', linewidth=2, label='SelectionSort')
    plt.plot([100, 1000, 10000, 100000], exec_time[2], ':', linewidth=2, label='InsertionSort')
    plt.plot([100, 1000, 10000, 100000], exec_time[3], linewidth=2, label='CocktailSort')
    plt.title(title, fontsize=14)
    plt.xlabel('Tamanho do Vetor', fontsize=14)
    plt.ylabel('Tempo de execução (ms)', fontsize=14)
    plt.tick_params(axis='both', which='major', labelsize=12)
    plt.yscale('log')
    plt.xscale('log')
    plt.legend()
    plt.grid(True)
    
    fig2 = plt.gcf()
    fig2.savefig(fig_name, format='png')
    
    plt.show()

# %%
exec_time = [
    [0.06743, 6.3476, 625.787000, 65103.234],
    [0.07809, 3.1934, 311.77, 31479.016],
    [0.00169, 0.0097, 0.134, 1.015],
    [0.00182, 0.0145, 0.095, 1.059]
]
plot_line_chart(exec_time, 'Vetor Ordenado', 'vetor_ordenado.png')

# %%
exec_time = [
    [0.10606, 10.6057, 1081.858, 110085.841],
    [0.03462, 3.2313, 326.792, 31562.794],
    [0.03855, 3.3641, 329.197, 33682.817],
    [0.06751, 6.6752, 772.77, 66611.367]
]
plot_line_chart(exec_time, 'Vetor Ordenado Reversamente', 'vetor_reverso.png')

# %%
exec_time = [
    [0.10056, 10.1064, 987.873, 102202.338],
    [0.04203, 3.3911, 326.023, 31514.586],
    [0.02146, 1.6853, 163.153, 16724.626],
    [0.05047, 5.2507, 623.009, 47118.358]
]
plot_line_chart(exec_time, 'Vetor Aleatório', 'vetor_random.png')
